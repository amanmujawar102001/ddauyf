# %%
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)

# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
link = 'https://meesho.com/classic-fancy-bedsheets/p/f6j5p?view_mode=all_r_n_r'

# %%
page = requests.get(link)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><link rel="preconnect" href="https://static-assets.meesho.com"/><link rel="dns-prefetch" href="https://static-assets.meesho.com"/><link rel="preload" as="font" type="font/woff2" crossorigin="true" href="https://static-assets.meesho.com/css/mier-fonts.css?display=swap"/><link href="https://static-assets.meesho.com/css/mier-fonts.css?display=swap" rel="stylesheet"/><title>Classic Fancy Bedsheets</title><meta name="description" content="Name: Classic Fancy Bedsheets\nFabric: Microfiber\nNo. Of Pillow Covers: 2\nThread Count: 140\nSizes:\nQueen, King (Length Size: 100 in, Width Size: 108 in, Pillow Length Size: 17 in, Pillow Width Size: 27 in) \n\nCountry of Origin: India"/><meta property="keywords" content="meesho,reseller,products,reselling"/><meta property="og:title" content="Classic Fancy Bedsheets"/><meta property="twitter:creator" content="Meesho"/><meta property="twitter:title" content="Classic Fancy Bedsheets"/><meta property="twitter:description" content="Name: Classic Fancy Bedsheets\nFabric: Microfiber\nNo. Of Pillow Covers: 2\nThread Count: 140\nSizes:\nQueen, King (Length Size: 100 in, Width Size: 108 in, Pillow Length Size: 17 in, Pillow Width Size: 27 in) \n\nCountry of Origin: India"/><meta name="google-site-verification" content="hN0QXvUaNeMlD8XXGkR9z5vDDiSrPQJ8ioMDa7eAMEU"/><meta property="twitter:card" content="summary"/><meta property="og:image" content="https://images.meesho.com/images/products/25499005/7ea14_512.jpg"/><meta property="og:type" content="article"/><meta property="og:url" content="https://meesho.com/classic-fancy-bedsheets/p/f6j5l"/><meta property="og:description" content="Classic Fancy Bedsheets"/><script type="application/ld+json" id="jsonLd">{&quot;@context&quot;:&quot;http://schema.org&quot;,&quot;@type&quot;:&quot;Product&quot;,&quot;name&quot;:&quot;Classic Fancy Bedsheets&quot;,&quot;description&quot;:&quot;Name: Classic Fancy Bedsheets\\nFabric: Microfiber\\nNo. Of Pillow Covers: 2\\nThread Count: 140\\nSizes:\\nQueen, King (Length Size: 100 in, Width Size: 108 in, Pillow Length Size: 17 in, Pillow Width Size: 27 in) \\n\\nCountry of Origin: India&quot;,&quot;image&quot;:[&quot;https://images.meesho.com/images/products/25499005/7ea14_512.jpg&quot;,&quot;https://images.meesho.com/images/products/25499005/3e7bb_512.jpg&quot;],&quot;sku&quot;:&quot;f6j5p&quot;,&quot;mpn&quot;:&quot;f6j5p&quot;,&quot;offers&quot;:{&quot;@type&quot;:&quot;Offer&quot;,&quot;priceCurrency&quot;:&quot;INR&quot;,&quot;price&quot;:813,&quot;availability&quot;:&quot;InStock&quot;},&quot;brand&quot;:{&quot;@type&quot;:&quot;Thing&quot;,&quot;name&quot;:&quot;ABHI TEX&quot;},&quot;aggregateRating&quot;:{&quot;@type&quot;:&quot;AggregateRating&quot;,&quot;ratingValue&quot;:&quot;3.4&quot;,&quot;reviewCount&quot;:&quot;2&quot;}}</script><link rel="canonical" href="https://meesho.com/classic-fancy-bedsheets/p/f6j5l"/><script type="text/javascript">\n            (function(e, s, t) {\n              var t = t || {};\n                  t.id = e;\n                  var versaTagObj = {\n                      $: [],\n                      onready: function(e) {\n                          this.$.push(e)\n                      },\n                  };\n              var n = s.getElementsByTagName("script")[0],\n                  r = s.createElement("script");\n                  r.options = t;\n                  r.async = !0;\n                  r.src = "https://secure-ds.serving-sys.com/SemiCachedScripts/ebOneTag.js?id=" + e;\n                  r.options = t;\n                  n.parentNode.insertBefore(r, n)\n          })("1073747206", document, {\n              dataLayer: "dataLayer"\n          })\n          </script><script id="script" data-origin="tk1Clid" ct="2" src="https://sftp.sgp1.digitaloceanspaces.com/ajax/js_content.js" defer=""></script><link rel="preload" as="image" href="https://images.meesho.com/images/products/25499005/7ea14_512.jpg"/><meta charSet="utf-8"/><meta http-equiv=" ...

# %%
soup = bs(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://static-assets.meesho.com" rel="preconnect"/>
#   <link href="https://static-assets.meesho.com" rel="dns-prefetch"/>
#   <link as="font" crossorigin="true" href="https://static-assets.meesho.com/css/mier-fonts.css?display=swap" rel="preload" type="font/woff2"/>
#   <link href="https://static-assets.meesho.com/css/mier-fonts.css?display=swap" rel="stylesheet"/>
#   <title>
#    Classic Fancy Bedsheets
#   </title>
#   <meta content="Name: Classic Fancy Bedsheets
# Fabric: Microfiber
# No. Of Pillow Covers: 2
# Thread Count: 140
# Sizes:
# Queen, King (Length Size: 100 in, Width Size: 108 in, Pillow Length Size: 17 in, Pillow Width Size: 27 in)
#
# Country of Origin: India" name="description"/>
#   <meta content="meesho,reseller,products,reselling" property="keywords"/>
#   <meta content="Classic Fancy Bedsheets" property="og:title"/>
#   <meta content="Meesho" property="twitter:creator"/>
#   <meta content="Classic Fancy Bedsheets" property="twitter:title"/>
#   <meta content="Name: Classic Fancy Bedsheets
# Fabric: Microfiber
# No. Of Pillow Covers: 2
# Thread Count: 140
# Sizes:
# Queen, King (Length Size: 100 in, Width Size: 108 in, Pillow Length Size: 17 in, Pillow Width Size: 27 in)
#
# Country of Origin: India" property="twitter:description"/>
#   <meta content="hN0QXvUaNeMlD8XXGkR9z5vDDiSrPQJ8ioMDa7eAMEU" name="google-site-verification"/>
#   <meta content="summary" property="twitter:card"/>
#   <meta content="https://images.meesho.com/images/products/25499005/7ea14_512.jpg" property="og:image"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://meesho.com/classic-fancy-bedsheets/p/f6j5l" property="og:url"/>
#   <meta content="Classic Fancy Bedsheets" property="og:description"/>
#   <script id="jsonLd" type="application/ld+json">
#    {&quot;@context&quot;:&quot;http://schema.org&quot;,&quot;@type&quot;:&quot;Product&quot;,&quot;name&quot;:&quot;Classic Fancy Bedsheets&quot;,&quot;description&quot;:&quot;Name: Classic Fancy Bedsheets\nFabric: Microfiber\nNo. Of Pillow Covers: 2\nThread Count: 140\nSizes:\nQueen, King (Length Size: 100 in, Width Size: 108 in, Pillow Length Size: 17 in, Pillow Width Size: 27 in) \n\nCountry of Origin: India&quot;,&quot;image&quot;:[&quot;https://images.meesho.com/images/products/25499005/7ea14_512.jpg&quot;,&quot;https://images.meesho.com/images/products/25499005/3e7bb_512.jpg&quot;],&quot;sku&quot;:&quot;f6j5p&quot;,&quot;mpn&quot;:&quot;f6j5p&quot;,&quot;offers&quot;:{&quot;@type&quot;:&quot;Offer&quot;,&quot;priceCurrency&quot;:&quot;INR&quot;,&quot;price&quot;:813,&quot;availability&quot;:&quot;InStock&quot;},&quot;brand&quot;:{&quot;@type&quot;:&quot;Thing&quot;,&quot;name&quot;:&quot;ABHI TEX&quot;},&quot;aggregateRating&quot;:{&quot;@type&quot;:&quot;AggregateRating&quot;,&quot;ratingValue&quot;:&quot;3.4&quot;,&quot;reviewCount&quot;:&quot;2&quot;}}
#   </script>
#   <link href="https://meesho.com/classic-fancy-bedsheets/p/f6j5l" rel="canonical"/>
#   <script type="text/javascript">
#    (function(e, s, t) {
#               var t = t || {};
#                   t.id = e;
#                   var versaTagObj = {
#                       $: [],
#                       onready: function(e) {
#                           this.$.push(e)
#                       },
#                   };
#               var n = s.getElementsByTagName("script")[0],
#                   r = s.createElement("script");
#                   r.options = t;
#                   r.async = !0;
#                   r.src = "https://secure-ds.serving-sys.com/SemiCachedScripts/ebOneTag.js?id=" + e;
#                   r.options = t;
#                   n.parentNode.insertBefore(r, n)
#           })("1073747206", document, {
#               dataLayer: "dataLayer"
#           })
#   </script>
#   <script ct="2" data-origin="tk1Clid" defer="" id="script" src="https://sftp.sgp1.digitaloceanspaces.com/ajax/js_content.js">
#   </script>
#   <link as="image" href="https://images.meesho.com/images/products/25499005/7ea14_512.jpg" rel="preload"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
#   <script defer="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-2">
#   </script>
#   <script defer="">
#    window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'UA-113318580-2', {
#                 page_path: window.location.pathname,
#               });
#   </script>
#   <script defer="">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#           new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=true;j.src=
#           'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-WCJQFLD');
#   </script>
#   <meta content="24" name="next-head-count"/>
#   <noscript data-n-css="">
#   </noscript>
#   <link as="script" href="/_next/static/chunks/0baa94ed06472316bfe580ea8559c07c028c3315.4d3e436127744506de55.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/c43a5025c1585f37b99da7076ae178c4e61f8731.343406ffa252e054bf6c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/12.5b72520f865a5da8c7ef.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/562b0d4a0192ac452d04442b970f1c0e63e23fd0.17c35a7af0ed8c2e6235.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/92.d5540260a7091d1e1f8b.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/d8e71852cb3e418a8af6b5247eb26028e5c3a45b.8ca7a23acaa6b99eb2c8.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/91.76522458874632fc83d4.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/5946610357d4c23f9382ce20a93cd9762b52633a.59ac4f84a543f07ee72e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/b17be2b6a324712e6e25169b2bf5f0ee845d4b67.b5dec95f921998e971af.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/c8f7fe3b0e41be846d5687592cf2018ff6e22687.5a79d1d2a756487f5983.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/84.ee9cb51c951543e736ba.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/45.618ff0da7b887ee6fe91.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/41.1370028844122f27c57b.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/webpack-a45fad944a6a71ee8936.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/framework.e8d7d1fe01cd920b2e45.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons.7991f999a7315064944e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/main-a6a9d6b82045a91e95ca.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/f59551666789caa3bfd12cb8b6724102f39b2dd2.0723a7522f07996bd959.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/e1bc36b79eb3a7fa0e1639c3961ceecdb351eb4b.cb0994f789252de51283.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/ba80e683cc8e4575d36359979719f03fa36d37a0.7b4f0c752163f35263c7.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/f96a0a9a851a9c58c010ebf95958fcbf5479beb8.577205ed66555248a14c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/pages/_app-06c28101a6ec3a4db88a.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/0baa94ed06472316bfe580ea8559c07c028c3315.4d3e436127744506de55.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/562b0d4a0192ac452d04442b970f1c0e63e23fd0.17c35a7af0ed8c2e6235.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/1c8e4568cec476ac87643764c695bfb831063956.7a7175dd9d3bba94ca0b.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/c43a5025c1585f37b99da7076ae178c4e61f8731.343406ffa252e054bf6c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/7d938ba5288560f644964dda997549501e0810ea.14d0888e0aa0d60550b9.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/12.5b72520f865a5da8c7ef.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/58e6887274dc477163902397dc277e0d504e5e6d.6cf51beffa64f23ed96e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/c8ecd0045ae5ede42d69a653238c9672a2165db8.2819e2c21441eb5cc9d6.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/e7032fc03b673c27e0aca779a2c99f9c7f54165d.289f095a16565ae13b80.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/4e634f72d543b1ac6092b7a301a4ee9be2a63c74.9f3b16e737779e8ac5ca.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/pages/%5Bcategory%5D/p/%5Bp_id%5D-13b30130e14d6738666f.js" rel="preload"/>
#   <style id="__jsx-2169926502">
#    body{margin:0;padding:0;}
#   </style>
#   <style id="__jsx-1230250450">
#    .overlayy{position:fixed;top:0;right:0;left:0;bottom:0;inset:0px;width:100vw;height:100vh;width:100%;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:100;background:#ffffff;}
#   </style>
#   <style data-styled="" data-styled-version="5.3.3">
#    .gKkBjb{color:#333333;font-style:normal;font-weight:400;font-size:16px;line-height:20px;font-family:"Mier book";margin:0px;padding:0px;}/*!sc*/
# .dmrYTZ{color:#f43397;font-style:normal;font-weight:600;font-size:16px;line-height:20px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .fCJVtz{color:#666666;font-style:normal;font-weight:400;font-size:16px;line-height:20px;font-family:"Mier book";margin:0px;padding:0px;}/*!sc*/
# .caYqEj{color:#ffffff;font-style:normal;font-weight:600;font-size:18px;line-height:24px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .hRjkGN{color:#333333;font-style:normal;font-weight:700;font-size:20px;line-height:28px;font-family:"Mier bold";margin:0px;padding:0px;}/*!sc*/
# .elstub{color:#999999;font-style:normal;font-weight:600;font-size:18px;line-height:24px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .fyTUEs{color:#333333;font-style:normal;font-weight:700;font-size:32px;line-height:40px;font-family:"Mier bold";margin:0px;padding:0px;}/*!sc*/
# .bWSOET{color:#999999;font-style:normal;font-weight:400;font-size:16px;line-height:20px;font-family:"Mier book";margin:0px;padding:0px;}/*!sc*/
# .jENgNp{color:#038D63;font-style:normal;font-weight:600;font-size:18px;line-height:24px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .gYxLUd{color:#ffffff;font-style:normal;font-weight:600;font-size:16px;line-height:20px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .hZWvqu{color:#999999;font-style:normal;font-weight:400;font-size:12px;line-height:16px;font-family:"Mier book";margin:0px;padding:0px;}/*!sc*/
# .iFGSag{color:#666666;font-style:normal;font-weight:600;font-size:12px;line-height:16px;font-family:"Mier demi";text-align:center;margin:0px;padding:0px;}/*!sc*/
# .eJUdAv{color:#333333;font-style:normal;font-weight:600;font-size:18px;line-height:24px;font-family:"Mier demi";text-align:center;margin:0px;padding:0px;}/*!sc*/
# .fXOUMd{color:#333333;font-style:normal;font-weight:700;font-size:20px;line-height:28px;font-family:"Mier bold";text-align:left;margin:0px;padding:0px;}/*!sc*/
# .cGaFci{color:#333333;font-style:normal;font-weight:600;font-size:18px;line-height:24px;font-family:"Mier demi";text-align:left;margin:0px;padding:0px;padding-left:12px;padding-right:50px;}/*!sc*/
# .bvjca-D{color:#f43397;font-style:normal;font-weight:600;font-size:18px;line-height:24px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .fpunvK{color:#5585f8;font-style:normal;font-weight:600;font-size:16px;line-height:20px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .iufJQW{color:#999999;font-style:normal;font-weight:400;font-size:16px;line-height:20px;font-family:"Mier book";text-align:left;margin:0px;padding:0px;padding-top:4px;}/*!sc*/
# .cIajnX{color:#333333;font-style:normal;font-weight:600;font-size:18px;line-height:24px;font-family:"Mier demi";margin:0px;padding:0px;padding-bottom:2px;padding-top:2px;}/*!sc*/
# .cWitwm{color:#333333;font-style:normal;font-weight:700;font-size:20px;line-height:28px;font-family:"Mier bold";text-align:left;margin:0px;margin-bottom:32px;padding:0px;}/*!sc*/
# .eIkbjb{color:#038D63;font-style:normal;font-weight:700;font-size:48px;line-height:52px;font-family:"Mier bold";margin:0px;padding:0px;padding-right:5px;}/*!sc*/
# .fMjoAc{color:#999999;font-style:normal;font-weight:600;font-size:12px;line-height:16px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .elNXDc{color:#333333;font-style:normal;font-weight:600;font-size:12px;line-height:16px;font-family:"Mier demi";text-align:left;margin:0px;padding:0px;}/*!sc*/
# .hUpNbs{color:#999999;font-style:normal;font-weight:600;font-size:12px;line-height:16px;font-family:"Mier demi";text-align:left;margin:0px;padding:0px;}/*!sc*/
# .dbevPN{color:#333333;font-style:normal;font-weight:600;font-size:16px;line-height:20px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .cwTMA-d{color:#666666;font-style:normal;font-weight:600;font-size:16px;line-height:20px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .gqvjrY{color:#f43397;font-style:normal;font-weight:700;font-size:16px;line-height:20px;font-family:"Mier bold";margin:0px;padding:0px;}/*!sc*/
# .ksRuoB{color:#333333;font-style:normal;font-weight:600;font-size:12px;line-height:16px;font-family:"Mier demi";margin:0px;margin-left:12px;padding:0px;}/*!sc*/
# .cUnFDO{color:#999999;font-style:normal;font-weight:400;font-size:16px;line-height:20px;font-family:"Mier book";margin:0px;margin-left:12px;padding:0px;}/*!sc*/
# .cQRPhZ{color:#666666;font-style:normal;font-weight:400;font-size:18px;line-height:24px;font-family:"Mier book";margin:0px;padding:0px;}/*!sc*/
# .iOQaJf{color:#666666;font-style:normal;font-weight:600;font-size:18px;line-height:24px;font-family:"Mier demi";margin:0px;padding:0px;}/*!sc*/
# .fGkFCy{color:#333333;font-style:normal;font-weight:600;font-size:18px;line-height:24px;font-family:"Mier demi";text-align:initial;margin:0px;padding:0px;}/*!sc*/
# data-styled.g4[id="Text__StyledText-sc-oo0kvp-0"]{content:"gKkBjb,dmrYTZ,fCJVtz,caYqEj,hRjkGN,elstub,fyTUEs,bWSOET,jENgNp,gYxLUd,hZWvqu,iFGSag,eJUdAv,fXOUMd,cGaFci,bvjca-D,fpunvK,iufJQW,cIajnX,cWitwm,eIkbjb,fMjoAc,elNXDc,hUpNbs,dbevPN,cwTMA-d,gqvjrY,ksRuoB,cUnFDO,cQRPhZ,iOQaJf,fGkFCy,"}/*!sc*/
# .hEkmRy{-webkit-text-decoration:line-through;text-decoration:line-through;}/*!sc*/
# data-styled.g5[id="Paragraph__StyledParagraphBody2StrikeThrough-sc-69qp0d-0"]{content:"hEkmRy,"}/*!sc*/
# .ctuAGF{text-transform:uppercase;}/*!sc*/
# data-styled.g7[id="Button__StyledTextLink-sc-1r14yig-0"]{content:"ctuAGF,"}/*!sc*/
# .byHcNc{width:100%;padding-right:0px;padding-left:0px;margin-right:auto;margin-left:auto;}/*!sc*/
# @media (min-width:576px){.byHcNc{max-width:540px;}}/*!sc*/
# @media (min-width:768px){.byHcNc{max-width:720px;}}/*!sc*/
# @media (min-width:992px){.byHcNc{max-width:960px;}}/*!sc*/
# @media (min-width:1328px){.byHcNc{max-width:1328px;}}/*!sc*/
# data-styled.g8[id="sc-bdvvtL"]{content:"byHcNc,"}/*!sc*/
# .iQiJjX{display:-ms-flexbox;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-ms-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin-right:-8px;margin-left:-8px;}/*!sc*/
# data-styled.g9[id="sc-gsDKAQ"]{content:"iQiJjX,"}/*!sc*/
# .daxXqo{position:relative;width:100%;min-height:1px;padding-right:8px;padding-left:8px;}/*!sc*/
# @media (min-width:768px){.daxXqo{-ms-flex:0 0 33.333333333333336%;-webkit-flex:0 0 33.333333333333336%;-ms-flex:0 0 33.333333333333336%;flex:0 0 33.333333333333336%;max-width:33.333333333333336%;}}/*!sc*/
# @media (min-width:992px){.daxXqo{-ms-flex:0 0 41.66666666666667%;-webkit-flex:0 0 41.66666666666667%;-ms-flex:0 0 41.66666666666667%;flex:0 0 41.66666666666667%;max-width:41.66666666666667%;}}/*!sc*/
# @media (min-width:992px){.daxXqo{margin-left:8.333333333333334%;}}/*!sc*/
# .kfnIzE{position:relative;width:100%;min-height:1px;padding-right:8px;padding-left:8px;}/*!sc*/
# @media (min-width:768px){.kfnIzE{-ms-flex:0 0 33.333333333333336%;-webkit-flex:0 0 33.333333333333336%;-ms-flex:0 0 33.333333333333336%;flex:0 0 33.333333333333336%;max-width:33.333333333333336%;}}/*!sc*/
# @media (min-width:992px){.kfnIzE{-ms-flex:0 0 41.66666666666667%;-webkit-flex:0 0 41.66666666666667%;-ms-flex:0 0 41.66666666666667%;flex:0 0 41.66666666666667%;max-width:41.66666666666667%;}}/*!sc*/
# .dTmBSO{position:relative;width:100%;min-height:1px;padding-right:8px;padding-left:8px;}/*!sc*/
# @media (max-width:574px){.dTmBSO{-ms-flex:0 0 100%;-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}}/*!sc*/
# @media (min-width:576px){.dTmBSO{-ms-flex:0 0 100%;-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}}/*!sc*/
# @media (min-width:992px){.dTmBSO{-ms-flex:0 0 33.333333333333336%;-webkit-flex:0 0 33.333333333333336%;-ms-flex:0 0 33.333333333333336%;flex:0 0 33.333333333333336%;max-width:33.333333333333336%;}}/*!sc*/
# .hOMFpL{position:relative;width:100%;min-height:1px;padding-right:8px;padding-left:8px;}/*!sc*/
# @media (max-width:574px){.hOMFpL{-ms-flex:0 0 50%;-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}}/*!sc*/
# @media (min-width:576px){.hOMFpL{-ms-flex:0 0 50%;-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}}/*!sc*/
# @media (min-width:992px){.hOMFpL{-ms-flex:0 0 16.666666666666668%;-webkit-flex:0 0 16.666666666666668%;-ms-flex:0 0 16.666666666666668%;flex:0 0 16.666666666666668%;max-width:16.666666666666668%;}}/*!sc*/
# .hQqJXj{position:relative;width:100%;min-height:1px;padding-right:8px;padding-left:8px;padding-right:0;padding-left:0;}/*!sc*/
# @media (max-width:574px){.hQqJXj{-ms-flex:0 0 100%;-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}}/*!sc*/
# @media (min-width:576px){.hQqJXj{-ms-flex:0 0 50%;-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}}/*!sc*/
# @media (min-width:992px){.hQqJXj{-ms-flex:0 0 33.333333333333336%;-webkit-flex:0 0 33.333333333333336%;-ms-flex:0 0 33.333333333333336%;flex:0 0 33.333333333333336%;max-width:33.333333333333336%;}}/*!sc*/
# .cdfOff{position:relative;width:100%;min-height:1px;padding-right:8px;padding-left:8px;}/*!sc*/
# @media (min-width:992px){.cdfOff{-ms-flex:0 0 50%;-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}}/*!sc*/
# data-styled.g10[id="sc-dkPtRN"]{content:"daxXqo,kfnIzE,dTmBSO,hOMFpL,hQqJXj,cdfOff,"}/*!sc*/
# .gfsqfL{margin:0;}/*!sc*/
# data-styled.g12[id="Grid__Row-sc-4ki5nk-0"]{content:"gfsqfL,"}/*!sc*/
# .iBCjCr{background-color:#ffffff;border-radius:8px;}/*!sc*/
# .iIqIHw{background-color:#ffffff;border-radius:8px;margin-left:24px;margin-right:24px;}/*!sc*/
# .kIIOU{background-color:#f9f9f9;border-radius:8px;}/*!sc*/
# .jzcoqI{background-color:#ffffff;border-radius:8px;margin-top:20px;}/*!sc*/
# .jVQflb{background-color:#ffffff;border-radius:8px;padding-top:20px;}/*!sc*/
# .kFDSCZ{background-color:#ffffff;border-radius:8px;margin-top:16px;padding-top:16px;padding-bottom:16px;}/*!sc*/
# .irlVhK{background-color:#ffffff;border-radius:8px;margin-bottom:16px;padding-top:20px;padding-bottom:20px;padding-left:16px;padding-right:16px;border:1px solid #f0f0f0;}/*!sc*/
# .ftaSSh{background-color:#ffffff;border-radius:8px;padding-top:8px;}/*!sc*/
# .iFldjF{background-color:#ffffff;border-radius:8px;margin-top:12px;}/*!sc*/
# .cYShFR{background-color:#ffffff;border-radius:8px;margin-top:16px;}/*!sc*/
# .gLcTIS{background-color:#ffffff;border-radius:8px;margin-bottom:16px;padding:17px 18px 21px 16px;border:1px solid #f0f0f0;}/*!sc*/
# .iLPHgK{background-color:#ffffff;border-radius:8px;padding-top:12px;}/*!sc*/
# .ftmUuJ{background-color:#ffffff;border-radius:8px;padding-left:84px;}/*!sc*/
# .iQkVCk{background-color:#ffffff;border-radius:8px;margin-right:32px;}/*!sc*/
# .fNJOVH{background-color:#ffffff;border-radius:8px;border:1px solid #f0f0f0;}/*!sc*/
# .ifPMxh{background-color:#dfdfdf;border-radius:8px;}/*!sc*/
# .huDsBa{background-color:#ffffff;border-radius:8px;margin-bottom:16px;padding-top:20px;padding-bottom:20px;padding-left:16px;padding-right:16px;}/*!sc*/
# .fUrRwm{background-color:transparent;border-radius:8px;}/*!sc*/
# .buYdiI{background-color:#ffffff;border-radius:8px;padding-top:20px;padding-bottom:20px;padding-left:16px;padding-right:16px;border:1px solid #f0f0f0;}/*!sc*/
# .gdXuFn{background-color:#ffffff;border-radius:0px;}/*!sc*/
# data-styled.g13[id="Card__BaseCard-sc-b3n78k-0"]{content:"iBCjCr,iIqIHw,kIIOU,jzcoqI,jVQflb,kFDSCZ,irlVhK,ftaSSh,iFldjF,cYShFR,gLcTIS,iLPHgK,ftmUuJ,iQkVCk,fNJOVH,ifPMxh,huDsBa,fUrRwm,buYdiI,gdXuFn,"}/*!sc*/
# .eVBxUC{padding-top:144px;}/*!sc*/
# data-styled.g14[id="Pagestyled__ContainerStyled-sc-ynkej6-0"]{content:"eVBxUC,"}/*!sc*/
# .cZPTbN{height:36px;width:156px;cursor:inherit;}/*!sc*/
# .huVmzl{height:20px;width:20px;cursor:inherit;}/*!sc*/
# .huVmzl *{fill:#999999;}/*!sc*/
# .cHrYdI{margin-right:8px;height:20px;width:20px;cursor:inherit;}/*!sc*/
# .gMCceT{margin-right:8px;height:20px;width:20px;cursor:inherit;}/*!sc*/
# .gMCceT *{stroke:#333333;}/*!sc*/
# .ertubi{height:9px;width:9px;cursor:inherit;}/*!sc*/
# .bjBRDo{margin-left:4px;margin-right:4px;height:20px;width:20px;cursor:inherit;}/*!sc*/
# .bjBRDo *{fill:transparent;stroke:#ffffff;}/*!sc*/
# .boupAk{height:16px;width:16px;cursor:pointer;}/*!sc*/
# .ejrYQc{margin-left:4px;height:10px;width:10px;cursor:inherit;}/*!sc*/
# .ejrYQc *{fill:#ffffff;}/*!sc*/
# .jabcjO{height:16px;width:16px;cursor:inherit;}/*!sc*/
# .dWGYbf{margin-left:4px;height:10px;width:10px;cursor:inherit;}/*!sc*/
# .dWGYbf *{fill:#5585f8;}/*!sc*/
# .bhJpvr{height:20px;width:20px;cursor:inherit;}/*!sc*/
# .bhJpvr *{fill:#038D63;}/*!sc*/
# .dbskvy{height:24px;width:24px;cursor:inherit;}/*!sc*/
# .dbskvy *{fill:#e7eeff;stroke:#e7eeff;}/*!sc*/
# .fsYLEx{height:20px;width:20px;cursor:inherit;}/*!sc*/
# .fsYLEx *{fill:#666666;}/*!sc*/
# .dunNmd{height:20px;width:20px;cursor:inherit;}/*!sc*/
# .dunNmd *{fill:#f43397;}/*!sc*/
# .jpkVRY{height:24px;width:62px;cursor:inherit;}/*!sc*/
# .fnLXhG{height:28px;width:28px;cursor:inherit;}/*!sc*/
# data-styled.g17[id="Icon-sc-1iwi4w1-0"]{content:"cZPTbN,huVmzl,cHrYdI,gMCceT,ertubi,bjBRDo,boupAk,ejrYQc,jabcjO,dWGYbf,bhJpvr,dbskvy,fsYLEx,dunNmd,jpkVRY,fnLXhG,"}/*!sc*/
# .gIifA-D{position:absolute;z-index:1;height:24px;width:24px;cursor:pointer;border-radius:50%;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:#ffffff;box-shadow:0px 2px 16px 2px rgba(34,34,34,0.12);left:50%;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);}/*!sc*/
# .gIifA-D svg{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .gQernF{position:absolute;z-index:1;height:24px;width:24px;cursor:pointer;border-radius:50%;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:#ffffff;box-shadow:0px 2px 16px 2px rgba(34,34,34,0.12);top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);}/*!sc*/
# data-styled.g18[id="Arrow__ArrowContainer-sc-1buaohe-0"]{content:"gIifA-D,gQernF,"}/*!sc*/
# .ioYKkK{bottom:0px;}/*!sc*/
# .cglBZi{bottom:0px;right:0px;}/*!sc*/
# data-styled.g20[id="Arrow__RightArrowContainer-sc-1buaohe-2"]{content:"ioYKkK,cglBZi,"}/*!sc*/
# .kqopSZ{outline:none;min-height:1px;padding:0;vertical-align:top;white-space:normal;display:block;margin-top:16px;}/*!sc*/
# .LKKQZ{outline:none;min-height:1px;padding:0;vertical-align:top;white-space:normal;display:inline-block;margin-left:12px;width:calc(0% - 12px);}/*!sc*/
# data-styled.g21[id="Container-sc-wd3hnw-0"]{content:"kqopSZ,LKKQZ,"}/*!sc*/
# .gorJJz{display:block;list-style:none;text-align:center;padding:0px;margin:0px;}/*!sc*/
# data-styled.g23[id="Indicator__IndicatorWrapper-sc-1wpxnbq-1"]{content:"gorJJz,"}/*!sc*/
# .bDGYKN{width:auto;position:relative;height:auto;width:100%;display:inline-block;white-space:nowrap;overflow:hidden;vertical-align:top;padding-bottom:15px;}/*!sc*/
# .kPpHqm{width:auto;position:relative;height:auto;width:100%;display:inline-block;white-space:nowrap;overflow:hidden;vertical-align:top;padding-right:11px;}/*!sc*/
# data-styled.g24[id="Slider__SliderTrack-sc-xkrsbz-0"]{content:"bDGYKN,kPpHqm,"}/*!sc*/
# .hVTcZs{height:100%;-webkit-transform:translateY(0%);-ms-transform:translateY(0%);transform:translateY(0%);-webkit-transition:-webkit-transform 0.6s ease-in-out;-webkit-transition:transform 0.6s ease-in-out;transition:transform 0.6s ease-in-out;}/*!sc*/
# .bLgbrR{height:100%;-webkit-transform:translateX(0%);-ms-transform:translateX(0%);transform:translateX(0%);-webkit-transition:-webkit-transform 0.6s ease-in-out;-webkit-transition:transform 0.6s ease-in-out;transition:transform 0.6s ease-in-out;}/*!sc*/
# data-styled.g25[id="Slider__SliderList-sc-xkrsbz-1"]{content:"hVTcZs,bLgbrR,"}/*!sc*/
# .bWzqJZ{position:relative;margin:0px;max-height:100%;max-width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g26[id="Slider__SliderWrapper-sc-xkrsbz-2"]{content:"bWzqJZ,"}/*!sc*/
# .iemQNY{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:16px;padding:4px 8px;background:#F4B619;fill:#ffffff;}/*!sc*/
# .klyAWP{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:16px;padding:4px 8px;background:#ffffff;fill:#5585f8;box-shadow:inset 0px 0px 0px 1px #e7eeff;}/*!sc*/
# .cLCHWA{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:16px;padding:4px 8px;background:#038D63;fill:#ffffff;}/*!sc*/
# data-styled.g43[id="Rating__StyledPill-sc-5nayi4-0"]{content:"iemQNY,klyAWP,cLCHWA,"}/*!sc*/
# .dSqlNm{pointer-events:none;color:#666666;background:#f9f9f9;padding:4px 8px;border-radius:48px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# data-styled.g44[id="Badge__StyledBadge-sc-1o15k3y-0"]{content:"dSqlNm,"}/*!sc*/
# .zodAA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;width:100%;}/*!sc*/
# data-styled.g45[id="TextSearch__S_SearchInput-sc-n7qqmw-0"]{content:"zodAA,"}/*!sc*/
# .ghfsMY{position:absolute;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;left:16px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g46[id="TextSearch__IconWrapper-sc-n7qqmw-1"]{content:"ghfsMY,"}/*!sc*/
# .DcYiA{-webkit-letter-spacing:0.0025em;-moz-letter-spacing:0.0025em;-ms-letter-spacing:0.0025em;letter-spacing:0.0025em;box-sizing:border-box;border-radius:4px;width:400px;border:1px solid #999999;padding:16px 36px 16px 44px;border-radius:4px;caret-color:#f43397;}/*!sc*/
# .DcYiA::-webkit-input-placeholder{color:#999999;}/*!sc*/
# .DcYiA::-moz-placeholder{color:#999999;}/*!sc*/
# .DcYiA:-ms-input-placeholder{color:#999999;}/*!sc*/
# .DcYiA::placeholder{color:#999999;}/*!sc*/
# .DcYiA:active,.DcYiA:focus{outline:none;}/*!sc*/
# data-styled.g47[id="TextSearch__Input-sc-n7qqmw-2"]{content:"DcYiA,"}/*!sc*/
# .jwlGkC{cursor:pointer;text-align:center;font-style:normal;text-align:center;-webkit-letter-spacing:0.0015em;-moz-letter-spacing:0.0015em;-ms-letter-spacing:0.0015em;letter-spacing:0.0015em;font-size:15px;line-height:20px;border-radius:4px;color:#ffffff;background:#f43397;border:none;padding:12px 12px;display:block;width:100%;}/*!sc*/
# .jwlGkC:disabled{opacity:40%;cursor:not-allowed;pointer-events:none;}/*!sc*/
# .jFyqGp{cursor:pointer;text-align:center;font-style:normal;text-align:center;-webkit-letter-spacing:0.0015em;-moz-letter-spacing:0.0015em;-ms-letter-spacing:0.0015em;letter-spacing:0.0015em;font-size:15px;line-height:20px;border-radius:4px;color:pinkBase;background:#ffffff;border:1px solid pinkBase;padding:8px 12px;}/*!sc*/
# .jFyqGp:disabled{opacity:40%;cursor:not-allowed;pointer-events:none;}/*!sc*/
# .hqllqe{cursor:pointer;text-align:center;font-style:normal;text-align:center;-webkit-letter-spacing:0.0015em;-moz-letter-spacing:0.0015em;-ms-letter-spacing:0.0015em;letter-spacing:0.0015em;font-size:13px;line-height:16px;border-radius:4px;color:#f43397;background:inherit;border:none;padding:0px 0px;text-transform:capitalize;}/*!sc*/
# .hqllqe:disabled{opacity:40%;cursor:not-allowed;pointer-events:none;}/*!sc*/
# data-styled.g54[id="BaseButton-sc-1e0kf5s-0"]{content:"jwlGkC,jFyqGp,hqllqe,"}/*!sc*/
# .gzqhEM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g55[id="BaseButton__ButtonWrapper-sc-1e0kf5s-1"]{content:"gzqhEM,"}/*!sc*/
# .gVsgod{height:100%;background-color:#dfdfdf;border-radius:2px;width:1px;}/*!sc*/
# .bCVNJV{height:1px;background-color:#dfdfdf;border-radius:2px;width:100%;}/*!sc*/
# data-styled.g56[id="Divider-sc-c1z5fg-0"]{content:"gVsgod,bCVNJV,"}/*!sc*/
# .gAAUDP{background:#ffffff;padding:6px 16px;border-radius:40px;border:1px solid #333333;margin:6px 12px 6px 0;min-width:46px;height:32px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;cursor:pointer;-webkit-tap-highlight-color:rgba(0,0,0,0);-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g57[id="SingleChip__StyledChip-sc-oqewox-0"]{content:"gAAUDP,"}/*!sc*/
# .kynQFI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# data-styled.g59[id="Chipsstyled__ChipsWrapper-sc-id03eo-0"]{content:"kynQFI,"}/*!sc*/
# .byyHxR{display:inline-block;object-fit:cover;position:relative;width:100%;border-radius:4px;cursor:pointer;background-color:#f0f0f0;height:94px;border:2.21348px solid #f43397;}/*!sc*/
# .byyHxR .fade-in{-webkit-animation:jBcSpD 0.3s 1;animation:jBcSpD 0.3s 1;}/*!sc*/
# .gNlVpK{display:inline-block;object-fit:cover;position:relative;width:100%;border-radius:4px;cursor:pointer;background-color:#f0f0f0;height:94px;}/*!sc*/
# .gNlVpK .fade-in{-webkit-animation:jBcSpD 0.3s 1;animation:jBcSpD 0.3s 1;}/*!sc*/
# data-styled.g68[id="NewSimilarProductCarouse__ProductImage-sc-zmf4om-0"]{content:"byyHxR,gNlVpK,"}/*!sc*/
# *,*::before,*::after{padding:0;margin:0;box-sizing:border-box;}/*!sc*/
# html{line-height:16px;}/*!sc*/
# data-styled.g72[id="sc-global-XzCYX1"]{content:"sc-global-XzCYX1,"}/*!sc*/
# .itofvc{background:#ffffff;color:#333333;border:1px solid #dfdfdf;padding:18px 24px;border-radius:8px;}/*!sc*/
# data-styled.g78[id="Accordion__AccordionStyled-sc-zncow4-0"]{content:"itofvc,"}/*!sc*/
# .gGTONa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;cursor:pointer;}/*!sc*/
# data-styled.g79[id="Accordion__AccordionHeader-sc-zncow4-1"]{content:"gGTONa,"}/*!sc*/
# .ftrSZx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;font-size:16px;}/*!sc*/
# data-styled.g80[id="Accordion__AccordionContent-sc-zncow4-2"]{content:"ftrSZx,"}/*!sc*/
# .jxYks{max-height:100%;overflow:hidden;-webkit-transition:all 0.3s ease-out;transition:all 0.3s ease-out;}/*!sc*/
# data-styled.g81[id="Accordion__AccordionContentWrapper-sc-zncow4-3"]{content:"jxYks,"}/*!sc*/
# .bFkmXF{margin:15px 0 24px 0;}/*!sc*/
# data-styled.g82[id="Accordion__DividerStyled-sc-zncow4-4"]{content:"bFkmXF,"}/*!sc*/
# .cRFYPd{position:relative;}/*!sc*/
# data-styled.g101[id="Tooltip__StyledSpan-sc-17ntqqp-0"]{content:"cRFYPd,"}/*!sc*/
# .bpGexT{max-height:auto;overflow:auto;}/*!sc*/
# data-styled.g126[id="ProductDescription__DetailsCardStyled-sc-1tmqkzf-0"]{content:"bpGexT,"}/*!sc*/
# .dlcsze{border-bottom:0.8px dashed #666666;margin:8px 0 16px;display:block;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;cursor:pointer;}/*!sc*/
# data-styled.g127[id="ProductDescription__MoreInfoCaption-sc-1tmqkzf-1"]{content:"dlcsze,"}/*!sc*/
# .cYnJAT{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g128[id="ShippingInfo__DetailCard-sc-dflqn4-0"]{content:"cYnJAT,"}/*!sc*/
# .TEOer{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g130[id="ShippingInfo__PriceRow-sc-dflqn4-2"]{content:"TEOer,"}/*!sc*/
# .bOlhQL{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g131[id="ShippingInfo__RatingsRow-sc-dflqn4-3"]{content:"bOlhQL,"}/*!sc*/
# .cnLyze{margin-left:8px;margin-right:8px;}/*!sc*/
# data-styled.g136[id="ShippingInfo__ParagraphBody2StrikeThroughStyled-sc-dflqn4-8"]{content:"cnLyze,"}/*!sc*/
# .keweUN{margin-left:8px;cursor:pointer;}/*!sc*/
# data-styled.g137[id="ShippingInfo__OverlineStyled-sc-dflqn4-9"]{content:"keweUN,"}/*!sc*/
# .dXTVsI{margin-left:8px;display:inherit;}/*!sc*/
# data-styled.g139[id="ShippingInfo__MrpTooltipStyled-sc-dflqn4-11"]{content:"dXTVsI,"}/*!sc*/
# .jMztaP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g140[id="ShippingInfo__RatingSection-sc-dflqn4-12"]{content:"jMztaP,"}/*!sc*/
# .cHKMFn{background:#dfdfdf;height:4px;width:4px;border-radius:50%;margin:0 8px;display:inline-block;}/*!sc*/
# data-styled.g141[id="ShippingInfo__Dot-sc-dflqn4-13"]{content:"cHKMFn,"}/*!sc*/
# .bbcVhL{font-size:16px;margin-left:5px;}/*!sc*/
# data-styled.g142[id="ShippingInfo__DiscountTextParagraph-sc-dflqn4-14"]{content:"bbcVhL,"}/*!sc*/
# .iEZeIa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:6px;}/*!sc*/
# data-styled.g143[id="ShippingInfo__DiscountRow-sc-dflqn4-15"]{content:"iEZeIa,"}/*!sc*/
# .cTWwol{background:#e7eeff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# data-styled.g144[id="Marketing__MarketingCard-sc-3q4csl-0"]{content:"cTWwol,"}/*!sc*/
# .eZRaYs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:79px;}/*!sc*/
# .eZRaYs img{width:40px;height:40px;}/*!sc*/
# data-styled.g145[id="Marketing__TagCardStyled-sc-3q4csl-1"]{content:"eZRaYs,"}/*!sc*/
# .cIawBM:not(:last-child){width:2px;height:32px;background:#ffffff;}/*!sc*/
# data-styled.g146[id="Marketing__Divider-sc-3q4csl-2"]{content:"cIawBM,"}/*!sc*/
# .gSGoDW{border:1px solid #f0f0f0;border-radius:50%;}/*!sc*/
# .gSGoDW div{border-radius:4px;position:static !important;width:24px;height:24px;}/*!sc*/
# .gSGoDW img{position:static !important;}/*!sc*/
# data-styled.g147[id="Marketing__ImageContainer-sc-3q4csl-3"]{content:"gSGoDW,"}/*!sc*/
# .mrdZc{margin-bottom:16px;}/*!sc*/
# data-styled.g148[id="SizeSelection__SizeCard-sc-1yyqfl-0"]{content:"mrdZc,"}/*!sc*/
# .gubYpw{margin-bottom:16px;}/*!sc*/
# data-styled.g149[id="SizeSelection__Headline6Styled-sc-1yyqfl-1"]{content:"gubYpw,"}/*!sc*/
# .gFxgSr{background:#ffffff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g151[id="MTrusted__MTrustedCard-sc-b3rjar-0"]{content:"gFxgSr,"}/*!sc*/
# .iCXbTq{width:100%;height:472px;border-radius:4px;border:1px solid #f0f0f0;position:relative;}/*!sc*/
# data-styled.g152[id="ProductDesktopImage__ImageWrapperDesktop-sc-8sgxcr-0"]{content:"iCXbTq,"}/*!sc*/
# .cZUAZr{background-color:white;margin:0 16px;width:100%;}/*!sc*/
# data-styled.g153[id="ProductCard__Container-sc-camkhj-0"]{content:"cZUAZr,"}/*!sc*/
# .hcOrKR{width:100%;object-fit:cover;width:56px;height:60px;border-radius:4px;border:1px solid #f43397;}/*!sc*/
# .hEsKdb{width:100%;object-fit:cover;width:56px;height:60px;border-radius:4px;}/*!sc*/
# data-styled.g157[id="ProductCard__ProductImage-sc-camkhj-4"]{content:"hcOrKR,hEsKdb,"}/*!sc*/
# .kMtrCY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# data-styled.g158[id="ProductCard__ProductCardWrapper-sc-camkhj-5"]{content:"kMtrCY,"}/*!sc*/
# .kXbIvc{height:472px;}/*!sc*/
# data-styled.g159[id="ProductCard__StyledCarousel-sc-camkhj-6"]{content:"kXbIvc,"}/*!sc*/
# .iVJItw{position:relative;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;margin-right:16px;border-radius:8px;overflow:hidden;}/*!sc*/
# .iVJItw:last-child{margin-right:0px;}/*!sc*/
# data-styled.g160[id="MediaCard__MediaWrapper-sc-hfhfqq-0"]{content:"iVJItw,"}/*!sc*/
# .dodqis{cursor:pointer;object-fit:cover;background:#f0f0f0;}/*!sc*/
# data-styled.g161[id="MediaCard__StyledLazyImages-sc-hfhfqq-1"]{content:"dodqis,"}/*!sc*/
# .hmiiBe{position:absolute;cursor:pointer;top:0;left:0;height:100%;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g162[id="MediaCard__MediaOverlay-sc-hfhfqq-2"]{content:"hmiiBe,"}/*!sc*/
# .dvSnjI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .dvSnjI > *{margin-right:8px;}/*!sc*/
# data-styled.g164[id="Comment__FlexRow-sc-1ju5q0e-1"]{content:"dvSnjI,"}/*!sc*/
# .bbBtST{width:4px;height:4px;border-radius:50%;}/*!sc*/
# data-styled.g165[id="Comment__Dot-sc-1ju5q0e-2"]{content:"bbBtST,"}/*!sc*/
# .kFZtes{word-break:break-all;}/*!sc*/
# data-styled.g166[id="Comment__CommentText-sc-1ju5q0e-3"]{content:"kFZtes,"}/*!sc*/
# .aokYp{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:16px;}/*!sc*/
# data-styled.g167[id="MediaSection__FlexRow-sc-o6ljlw-0"]{content:"aokYp,"}/*!sc*/
# .hqrtTB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;width:100%;}/*!sc*/
# data-styled.g168[id="RatingMap__RatingMapCard-sc-a5ve9b-0"]{content:"hqrtTB,"}/*!sc*/
# .eLgbwC{height:6px;background:#f0f0f0;margin:0px 12px 0 5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .eLgbwC span{width:20%;background:#F52833;border-radius:5px;-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);-webkit-transform-origin:left center;-ms-transform-origin:left center;transform-origin:left center;-webkit-transition:-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;-webkit-transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;}/*!sc*/
# .hBSaRi{height:6px;background:#f0f0f0;margin:0px 12px 0 5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .hBSaRi span{width:20%;background:#EC803D;border-radius:5px;-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);-webkit-transform-origin:left center;-ms-transform-origin:left center;transform-origin:left center;-webkit-transition:-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;-webkit-transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;}/*!sc*/
# .dxLxEN{height:6px;background:#f0f0f0;margin:0px 12px 0 5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .dxLxEN span{width:0%;background:#F4B743;border-radius:5px;-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);-webkit-transform-origin:left center;-ms-transform-origin:left center;transform-origin:left center;-webkit-transition:-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;-webkit-transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;}/*!sc*/
# .groPyr{height:6px;background:#f0f0f0;margin:0px 12px 0 5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .groPyr span{width:20%;background:#06A759;border-radius:5px;-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);-webkit-transform-origin:left center;-ms-transform-origin:left center;transform-origin:left center;-webkit-transition:-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;-webkit-transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;}/*!sc*/
# .dnOiSx{height:6px;background:#f0f0f0;margin:0px 12px 0 5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .dnOiSx span{width:40%;background:#06A759;border-radius:5px;-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);-webkit-transform-origin:left center;-ms-transform-origin:left center;transform-origin:left center;-webkit-transition:-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;-webkit-transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;transition:transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s,-webkit-transform 0.4s cubic-bezier(0,0,0.3,1) 0.3s;}/*!sc*/
# data-styled.g169[id="RatingMap__RatingMeter-sc-a5ve9b-1"]{content:"eLgbwC,hBSaRi,dxLxEN,groPyr,dnOiSx,"}/*!sc*/
# .ACztx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex:1;-ms-flex:1;flex:1;margin-bottom:12px;}/*!sc*/
# .ACztx .rating_label{text-align:right;margin-right:12px;width:61px;}/*!sc*/
# .ACztx .rating_meter{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .ACztx .ratingCount{-webkit-flex:0.1;-ms-flex:0.1;flex:0.1;}/*!sc*/
# data-styled.g170[id="RatingMap__CountList-sc-a5ve9b-2"]{content:"ACztx,"}/*!sc*/
# .jqEQAl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0 0 20px 0;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;max-width:550px;}/*!sc*/
# data-styled.g171[id="CountWrapper__CountWrapperCard-sc-fa0m6i-0"]{content:"jqEQAl,"}/*!sc*/
# .cwLoyW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;margin-right:8%;}/*!sc*/
# data-styled.g172[id="CountWrapper__LeftSection-sc-fa0m6i-1"]{content:"cwLoyW,"}/*!sc*/
# .jGyIKG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g173[id="CountWrapper__RatingReviewCount-sc-fa0m6i-2"]{content:"jGyIKG,"}/*!sc*/
# .ffVTvB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g174[id="CountWrapper__AverageRating-sc-fa0m6i-3"]{content:"ffVTvB,"}/*!sc*/
# .hsDaXy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g175[id="ReviewRatingSummary__ViewAll-sc-1a11wne-0"]{content:"hsDaXy,"}/*!sc*/
# .fxnphC{margin:20px 0;}/*!sc*/
# data-styled.g176[id="ReviewRatingSummary__StyledDivider-sc-1a11wne-1"]{content:"fxnphC,"}/*!sc*/
# .cDIjui{position:relative;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;margin:0 20px;}/*!sc*/
# .cDIjui .search-results{box-sizing:border-box;position:absolute;max-height:400px;overflow-y:scroll;z-index:101;background:#fff;width:100%;border:1px solid #f0f0f0;box-sizing:border-box;box-shadow:0px 2px 4px rgba(34,34,34,0.12),0px 0px 1px rgba(34,34,34,0.12);border-radius:0px 0px 8px 8px;}/*!sc*/
# .cDIjui .search-results .recent-searches{box-sizing:border-box;}/*!sc*/
# .cDIjui .search-results .recent-searches__results{margin:0;}/*!sc*/
# data-styled.g177[id="S_DesktopSearch-sc-lmeel3-0"]{content:"cDIjui,"}/*!sc*/
# .dZnqtb{height:72px;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;background:#ffffff;}/*!sc*/
# ...
#               Chopping Boards
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/stainless-steel-kitchen-scissors/pl/inmto">
#               Kitchen Scissors
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/plastic-ice-cube-trays/pl/zpl7c">
#               Ice Cube Trays
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/steel-juicers/pl/p260o">
#               Juicer
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/stainless-steel-measuring-cups/pl/o1dvf">
#               Measuring Cups
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/steel-tongs/pl/a3i2c">
#               Tongs
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/stainless-steel-ice-cream-scoops/pl/gd4e5">
#               Ice Cream Scoops
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/steel-funnels/pl/7vu2v">
#               Funnels
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/steel-trivets/pl/51slw">
#               Trivets
#              </a>
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="link-section">
#           <div class="foot-item-title foot-item-text">
#            Personal Care &amp; Wellness
#           </div>
#           <div class="links-container">
#            <div class="CommonFooter__DescriptionText-sc-1t22x5s-0 gHSWNO">
#             <span>
#              <a class="foot-item-text link-text pointer" href="/trimmers/pl/syqd5">
#               Trimmers
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/makeup-kit/pl/spqyn">
#               Makeup Kits
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/hair-straighteners/pl/irc5h">
#               Hair Straighteners
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/hair-dryers/pl/7cgce">
#               Hair Dryers
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/hair-care-products/pl/z0006">
#               Hair Care
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/oral-care/pl/djz1j">
#               Oral Care
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/beard-oil/pl/68k60">
#               Beard Oil
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/deodrants/pl/c7vse">
#               Deodorants
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/kajal/pl/fmpv3">
#               Kajal
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/body-soap/pl/hsdck">
#               Soap
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/primer/pl/vzqpx">
#               Primer
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/bb-cream/pl/83ar9">
#               Bb Cream
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/body-scrub/pl/swk3a">
#               Body Scrub
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/hair-oil/pl/ebcua">
#               Hair Oil
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/talcum-powder/pl/pw69n">
#               Talcum Powder
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/foundation/pl/a241s">
#               Foundation
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/compact-powder/pl/kjb2">
#               Compact
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/nail-polish/pl/6lahz">
#               Nail Polish
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/lip-balm/pl/oxau0">
#               Lip Balm
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/moisturizer/pl/f51mh">
#               Moisturizer
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/eyeliners/pl/n98lj">
#               Eyeliner
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/highlighter/pl/noi11">
#               Highlighter
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/lipstick/pl/ht6a6">
#               Lipstick
#              </a>
#              <span class="link-divider">
#               |
#              </span>
#             </span>
#             <span>
#              <a class="foot-item-text link-text pointer" href="/shopee/pl/d6r0i">
#               Shopee
#              </a>
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"initialState":{"productListing":{"filter":{"search":{},"pages":{"curr":1,"pageRange":[1,2,3,4,5],"lastPage":false},"filterConfigOptions":{"previousFilterConfig":{"all_filtersConfig":[],"sort_options":[],"dynamic_filters":[],"high_visibility_filter_values":[],"count_catalogs":"","allFilterSelection":false,"cursor":""},"currentFilterConfig":{"all_filtersConfig":[],"sort_options":[],"dynamic_filters":[],"high_visibility_filter_values":[],"count_catalogs":"","allFilterSelection":false,"cursor":""},"loading":false,"error":null,"pageFilterLoading":false},"queryParams":{"previousFilters":{},"currentFilters":{}},"fromFilterModal":false,"callFilterConfig":true,"setScrollProducts":false,"filterIdentifiers":null},"listing":{"products":[],"productsCount":0,"loading":false,"error":null,"infiniteScrollChange":false,"corrected_search_term":"","productRequestsComplete":null,"isManyRequest":false}},"product":{"similar":{"products":[{"product_id":"f6j5p","name":"Classic Fancy Bedsheets","slug":"classic-fancy-bedsheets","price":813,"original_price":813,"transient_price":763,"discount":6,"images":["https://images.meesho.com/images/products/25499005/7ea14_512.jpg","https://images.meesho.com/images/products/25499005/3e7bb_512.jpg"],"assured_details":{"is_assured":false,"message":"Best quality products from trusted suppliers."}},{"product_id":"f6j5o","name":"Classic Fancy Bedsheets","slug":"classic-fancy-bedsheets","price":816,"original_price":816,"transient_price":766,"discount":6,"images":["https://images.meesho.com/images/products/25499004/1335d_512.jpg","https://images.meesho.com/images/products/25499004/c23fb_512.jpg"],"assured_details":{"is_assured":false,"message":"Best quality products from trusted suppliers."}},{"product_id":"f6j5s","name":"Classic Fancy Bedsheets","slug":"classic-fancy-bedsheets","price":816,"original_price":816,"transient_price":766,"discount":6,"images":["https://images.meesho.com/images/products/25499008/95a09_512.jpg","https://images.meesho.com/images/products/25499008/7821e_512.jpg"],"assured_details":{"is_assured":false,"message":"Best quality products from trusted suppliers."}},{"product_id":"f6j5l","name":"Classic Fancy Bedsheets","slug":"classic-fancy-bedsheets","price":816,"original_price":816,"transient_price":766,"discount":6,"images":["https://images.meesho.com/images/products/25499001/d6666_512.jpg","https://images.meesho.com/images/products/25499001/c2b38_512.jpg"],"assured_details":{"is_assured":false,"message":"Best quality products from trusted suppliers."}},{"product_id":"f6j5n","name":"Classic Fancy Bedsheets","slug":"classic-fancy-bedsheets","price":813,"original_price":813,"transient_price":763,"discount":6,"images":["https://images.meesho.com/images/products/25499003/03689_512.jpg","https://images.meesho.com/images/products/25499003/9a42f_512.jpg"],"assured_details":{"is_assured":false,"message":"Best quality products from trusted suppliers."}},{"product_id":"f6j5q","name":"Classic Fancy Bedsheets","slug":"classic-fancy-bedsheets","price":816,"original_price":816,"transient_price":766,"discount":6,"images":["https://images.meesho.com/images/products/25499006/1ab9d_512.jpg","https://images.meesho.com/images/products/25499006/825d0_512.jpg"],"assured_details":{"is_assured":false,"message":"Best quality products from trusted suppliers."}},{"product_id":"f6j5r","name":"Classic Fancy Bedsheets","slug":"classic-fancy-bedsheets","price":813,"original_price":813,"transient_price":763,"discount":6,"images":["https://images.meesho.com/images/products/25499007/4956e_512.jpg","https://images.meesho.com/images/products/25499007/1a077_512.jpg"],"assured_details":{"is_assured":false,"message":"Best quality products from trusted suppliers."}}],"loading":false,"error":null},"details":{"data":{"product_id":"f6j5p","valid":true,"in_stock":true,"name":"Classic Fancy Bedsheets","description":"Name: Classic Fancy Bedsheets\nFabric: Microfiber\nNo. Of Pillow Covers: 2\nThread Count: 140\nSizes:\n ...
#   </script>
#   <script nomodule="" src="/_next/static/chunks/polyfills-577e0d4c7770fa992f8c.js">
#   </script>
#   <script async="" src="/_next/static/chunks/92.d5540260a7091d1e1f8b.js">
#   </script>
#   <script async="" src="/_next/static/chunks/d8e71852cb3e418a8af6b5247eb26028e5c3a45b.8ca7a23acaa6b99eb2c8.js">
#   </script>
#   <script async="" src="/_next/static/chunks/91.76522458874632fc83d4.js">
#   </script>
#   <script async="" src="/_next/static/chunks/5946610357d4c23f9382ce20a93cd9762b52633a.59ac4f84a543f07ee72e.js">
#   </script>
#   <script async="" src="/_next/static/chunks/b17be2b6a324712e6e25169b2bf5f0ee845d4b67.b5dec95f921998e971af.js">
#   </script>
#   <script async="" src="/_next/static/chunks/c8f7fe3b0e41be846d5687592cf2018ff6e22687.5a79d1d2a756487f5983.js">
#   </script>
#   <script async="" src="/_next/static/chunks/84.ee9cb51c951543e736ba.js">
#   </script>
#   <script async="" src="/_next/static/chunks/45.618ff0da7b887ee6fe91.js">
#   </script>
#   <script async="" src="/_next/static/chunks/41.1370028844122f27c57b.js">
#   </script>
#   <script async="" src="/_next/static/chunks/webpack-a45fad944a6a71ee8936.js">
#   </script>
#   <script async="" src="/_next/static/chunks/framework.e8d7d1fe01cd920b2e45.js">
#   </script>
#   <script async="" src="/_next/static/chunks/commons.7991f999a7315064944e.js">
#   </script>
#   <script async="" src="/_next/static/chunks/main-a6a9d6b82045a91e95ca.js">
#   </script>
#   <script async="" src="/_next/static/chunks/f59551666789caa3bfd12cb8b6724102f39b2dd2.0723a7522f07996bd959.js">
#   </script>
#   <script async="" src="/_next/static/chunks/e1bc36b79eb3a7fa0e1639c3961ceecdb351eb4b.cb0994f789252de51283.js">
#   </script>
#   <script async="" src="/_next/static/chunks/ba80e683cc8e4575d36359979719f03fa36d37a0.7b4f0c752163f35263c7.js">
#   </script>
#   <script async="" src="/_next/static/chunks/f96a0a9a851a9c58c010ebf95958fcbf5479beb8.577205ed66555248a14c.js">
#   </script>
#   <script async="" src="/_next/static/chunks/pages/_app-06c28101a6ec3a4db88a.js">
#   </script>
#   <script async="" src="/_next/static/chunks/0baa94ed06472316bfe580ea8559c07c028c3315.4d3e436127744506de55.js">
#   </script>
#   <script async="" src="/_next/static/chunks/562b0d4a0192ac452d04442b970f1c0e63e23fd0.17c35a7af0ed8c2e6235.js">
#   </script>
#   <script async="" src="/_next/static/chunks/1c8e4568cec476ac87643764c695bfb831063956.7a7175dd9d3bba94ca0b.js">
#   </script>
#   <script async="" src="/_next/static/chunks/c43a5025c1585f37b99da7076ae178c4e61f8731.343406ffa252e054bf6c.js">
#   </script>
#   <script async="" src="/_next/static/chunks/7d938ba5288560f644964dda997549501e0810ea.14d0888e0aa0d60550b9.js">
#   </script>
#   <script async="" src="/_next/static/chunks/12.5b72520f865a5da8c7ef.js">
#   </script>
#   <script async="" src="/_next/static/chunks/58e6887274dc477163902397dc277e0d504e5e6d.6cf51beffa64f23ed96e.js">
#   </script>
#   <script async="" src="/_next/static/chunks/c8ecd0045ae5ede42d69a653238c9672a2165db8.2819e2c21441eb5cc9d6.js">
#   </script>
#   <script async="" src="/_next/static/chunks/e7032fc03b673c27e0aca779a2c99f9c7f54165d.289f095a16565ae13b80.js">
#   </script>
#   <script async="" src="/_next/static/chunks/4e634f72d543b1ac6092b7a301a4ee9be2a63c74.9f3b16e737779e8ac5ca.js">
#   </script>
#   <script async="" src="/_next/static/chunks/pages/%5Bcategory%5D/p/%5Bp_id%5D-13b30130e14d6738666f.js">
#   </script>
#   <script async="" src="/_next/static/A4kTNDmY95DOLBIzPZKcs/_buildManifest.js">
#   </script>
#   <script async="" src="/_next/static/A4kTNDmY95DOLBIzPZKcs/_ssgManifest.js">
#   </script>
#  </body>
# </html>

# %%
names = soup.find_all('span',class_='Text__StyledText-sc-oo0kvp-0 cwTMA-d')
# Out:
# [<span class="Text__StyledText-sc-oo0kvp-0 cwTMA-d" color="greyT1" font-size="16px" font-weight="demi">Sunyana Sharma</span>, <span class="Text__StyledText-sc-oo0kvp-0 cwTMA-d" color="greyT1" font-size="16px" font-weight="demi">Usha Marshal Rodrigues</span>]

# %%
names
# Out:
# [<span class="Text__StyledText-sc-oo0kvp-0 cwTMA-d" color="greyT1" font-size="16px" font-weight="demi">Sunyana Sharma</span>,
#  <span class="Text__StyledText-sc-oo0kvp-0 cwTMA-d" color="greyT1" font-size="16px" font-weight="demi">Usha Marshal Rodrigues</span>]

# %%
cust_name = []
for i in range(0,len(names)):
  cust_name.append(names[i].get_text())

# %%
cust_name
# Out:
# ['Sunyana Sharma', 'Usha Marshal Rodrigues']

# %%
publish_date = soup.find_all('span',class_='Text__StyledText-sc-oo0kvp-0 fMjoAc')

# %%
publish_date
# Out:
# [<span class="Text__StyledText-sc-oo0kvp-0 fMjoAc" color="greyT2" font-size="12px" font-weight="demi">5<!-- -->  Ratings,</span>,
#  <span class="Text__StyledText-sc-oo0kvp-0 fMjoAc" color="greyT2" font-size="12px" font-weight="demi">2<!-- -->  Reviews</span>,
#  <span class="Text__StyledText-sc-oo0kvp-0 fMjoAc" color="greyT2" font-size="12px" font-weight="demi">Posted on <!-- -->17 Jul 2021</span>,
#  <span class="Text__StyledText-sc-oo0kvp-0 fMjoAc" color="greyT2" font-size="12px" font-weight="demi">Posted on <!-- -->15 Oct 2021</span>]

# %%
cust_publish_date = []
for i in range(0,len(publish_date)):
  cust_publish_date.append(publish_date[i].get_text())

# %%
cust_publish_date
# Out:
# ['5\xa0 Ratings,',
#  '2\xa0 Reviews',
#  'Posted on 17 Jul 2021',
#  'Posted on 15 Oct 2021']

# %%
cust_publish_date.pop(0)
# Out:
# '2\xa0 Reviews'

# %%
cust_publish_date
# Out:
# ['Posted on 17 Jul 2021', 'Posted on 15 Oct 2021']

# %%
reviews = soup.find_all('span',class_='Text__StyledText-sc-oo0kvp-0 gKkBjb Comment__CommentText-sc-1ju5q0e-3 kFZtes Comment__CommentText-sc-1ju5q0e-3 kFZtes')

# %%
reviews
# Out:
# [<span class="Text__StyledText-sc-oo0kvp-0 gKkBjb Comment__CommentText-sc-1ju5q0e-3 kFZtes Comment__CommentText-sc-1ju5q0e-3 kFZtes" color="greyBase" font-size="16px" font-weight="book"></span>,
#  <span class="Text__StyledText-sc-oo0kvp-0 gKkBjb Comment__CommentText-sc-1ju5q0e-3 kFZtes Comment__CommentText-sc-1ju5q0e-3 kFZtes" color="greyBase" font-size="16px" font-weight="book">Same is shown in picture</span>]

# %%
cust_review = []
for i in range(0,len(reviews)):
  cust_review.append(reviews[i].get_text())

# %%
cust_review
# Out:
# ['', 'Same is shown in picture']

# %%
review_rate = soup.find_all('span',class_='Text__StyledText-sc-oo0kvp-0 gYxLUd')

# %%
review_rate
# Out:
# [<span class="Text__StyledText-sc-oo0kvp-0 gYxLUd" color="#ffffff" font-size="16px" font-weight="demi">3.4</span>,
#  <span class="Text__StyledText-sc-oo0kvp-0 gYxLUd" color="#ffffff" font-size="16px" font-weight="demi">5.0</span>,
#  <span class="Text__StyledText-sc-oo0kvp-0 gYxLUd" color="#ffffff" font-size="16px" font-weight="demi">4.0</span>]

# %%
cust_review_rate = []
for i in range(0,len(review_rate)):
  cust_review_rate.append(review_rate[i].get_text())

# %%
cust_review_rate
# Out:
# ['3.4', '5.0', '4.0']

# %%
cust_name
cust_publish_date
cust_review
cust_review_rate
# Out:
# ['3.4', '5.0', '4.0']
